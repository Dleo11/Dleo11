# %% [markdown]
# <a href="https://colab.research.google.com/github/Dleo11/Dleo11/blob/main/InmersionDatos__AluraProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase 01**

# %%
from google.colab import drive # permitir permisos de accesibilidad a tu contenido de drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # es recomendado meter alias
inmuebles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/inmuebles_bogota.csv') # ruta del archivo a trabajar
inmuebles.head() # trae las 5 primeros valores
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape # contenido de atributos y valores
# Out:
# (9520, 8)

# %%
inmuebles.columns # los tipos de atributos que existen
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños' : 'Banos', 'Área' : 'Area'} # key : value
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(10) # sample = muestras alelatorias
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1058         Casa                   Casa en venta en Cedritos             5
# 5744  Apartamento            Apartamento en venta en Fontibón             3
# 2320         Casa                Casa en venta en Pontevedra              3
# 3989  Apartamento            Apartamento en venta en El Batán             2
# 2702  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4051  Apartamento            Apartamento en venta en Cedritos             1
# 9146  Apartamento       Apartamento en venta en Puente Aranda             2
# 7900         Casa                 Casa en venta en Tunjuelito             8
# 3606  Apartamento         Apartamento en venta en Chico Norte             4
# 4541  Apartamento      Apartamento en venta en Barrios Unidos             2
#
#       Banos  Area              Barrio  \
# 1058      2   120            Cedritos
# 5744      1    53            Fontibón
# ...

# %%
inmuebles.info() # Es muy importante saber el tipo de contenido que hay en cada columna, para ello llamamos al .info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]  # que valores hay dentro del indice 299(recuerda que el indice empieza en 0)
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] #genera un intervalo de valores para mostrarlo en el data set
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300] # muestra el valor especifico que se desea
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305] # lo mismo que el de arriba pero con intervalos
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305]) # que tipo de valores encontramos en la salida(arrays en este caso)
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean() # la media aritmetica papus xd en general
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100) # una muestra de 100 valores random
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5139  Apartamento            Apartamento en venta en Cedritos             3
# 5851  Apartamento                Apartamento en venta en Bosa             2
# 8815  Apartamento   Apartamento en venta en Chapinero Central             1
# 2113  Apartamento      Apartamento en venta en Barrios Unidos             3
# 1149  Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 4494         Casa             Casa en venta en Barrios Unidos             3
# 2688  Apartamento            Apartamento en venta en Cedritos             3
# 770   Apartamento            Apartamento en venta en Cedritos             3
# 5138  Apartamento            Apartamento en venta en El Chicó             1
# 6178         Casa                    Casa en venta en El Plan             3
#
# ...

# %%
(inmuebles.Barrio == 'Chico Reservado')  # que inmuebles pertenecen a Chico Reservado
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado')) # el numero de inmuebles que hay
# Out:
# 225

# %%
inmuebles_chico = ((inmuebles.Barrio == 'Chico Reservado')) # si deseas guardar la salida , hazlo en una variable
inmuebles_chico
type(inmuebles_chico) # pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
chico_reservado =  inmuebles[inmuebles_chico] # esta variable mostrara una mascara(iframe) de los lugares que son de chico reservado
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean() # promedio general de chico reservado
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts()) # el conteo de barrios
# Out:
# 149

# %%
inmuebles.Barrio.value_counts() # cuantos inmuebles hay en cada barrio(de mayor a menor)
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts()) # el conteo de UPZs
# Out:
# 63

# %%
inmuebles.UPZ.value_counts() # el numero de barrios en las que no tenemos inmuebles a la venta en las data set en todas las upz de la ciudad de bogota
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar() # plot: para visualizar un grafico  bar(): grafico de barras(tipo de grafico)
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()  # los top 10 de los barrios
# Out:
# <Axes: >

# %% [markdown]
# # **Homework:**

# %% [markdown]
# 1. Promedio de area de todos los inmuebles en los barrios(ciento tantos)  del dataset(con grafico del top 10)
# 2. Consultar datos estadisticos, conteo, mediana, valores min y max

# %%
promedio_areas = inmuebles.groupby('Barrio')['Area'].mean()
promedio_areas
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
promedio_areas.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
promedio_areas.head(10).sort_values(ascending = False).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.describe() # conteo, promedio, desvio estandar, valor min, primer cuartil (25%), segundo cuartil(50%), tercer cuartil(75%), valor max
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
pd.set_option('display.precision',2)   #precion de solo 2 decimales
pd.describe_option('display.float_format', lambda x: '%.2f' % x)  #funciones lamda : aplicable a especificar algo sencillo
inmuebles.describe() 
#display.float_format : callable
"""    The callable should accept a floating point number and return
    a string with the desired format of the number. This is used
    in some places like SeriesFormatter.
    See formats.format.EngFormatter for an example.
   [default: None] [currently: None]
"""
# Out:
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: None]
# '    The callable should accept a floating point number and return\n    a string with the desired format of the number. This is used\n    in some places like SeriesFormatter.\n    See formats.format.EngFormatter for an example.\n   [default: None] [currently: None]\n'

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor
# 897  Usaquén  $ 480.000.000

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor
# 8401     2  San Cristobal  Sosiego  $ 180.000.000

# %% [markdown]
# # **AULA - 02**

# %%
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 1662  Apartamento            Apartamento en venta en Suba             2
# 6093  Apartamento            Apartamento en venta en Bosa             2
# 1652         Casa               Casa en venta en Fontibón             7
# 8138         Casa                   Casa en venta en Suba             3
# 4840  Apartamento  Apartamento en venta en Barrios Unidos             2
# 3925  Apartamento         Apartamento en venta en Usaquén             2
# 1729  Apartamento         Apartamento en venta en Kennedy             2
# 9091         Casa        Casa en venta en Chico Reservado             3
# 5488  Apartamento         Apartamento en venta en Usaquén             3
# 1449  Apartamento   Apartamento en venta en San Cristobal             2
#
#       Banos  Area           Barrio                                 UPZ  \
# 1662      2    91             Suba                                Suba
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0] # el tipo de dato que tenemos dentro del atributo Valor esta en object(str) '$ 360.000.000'
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] #  '$ 360.000.000$ 670.000.000' tenerlo en cuento, debemos aplicar funciones str
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0].split()  # split separa una cadena de texto en funcion a algun parametro, pero por default sera el espacio el separador
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split() # en esta operacion nos devuelve cada elemento en formato lista. columna de series
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %%
inmuebles.Valor.str.split(expand = True) # mostrara un dataframe con 2 columnas
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor = inmuebles.Valor.str.split(expand = True) 
inmuebles['Moneda'] = valor[0] # 1ra columna
inmuebles['Precio'] = valor[1] # 2da columna
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 4227  Apartamento  Apartamento en venta en Barrios Unidos             2
# 7500  Apartamento         Apartamento en venta en Kennedy             3
# 9293  Apartamento         Apartamento en venta en Usaquén             3
#
#       Banos  Area          Barrio              UPZ          Valor Moneda  \
# 4227      1    38  Barrios Unidos        Los Andes  $ 175.000.000      $
# 7500      1    49         Kennedy  Kennedy Central  $ 250.000.000      $
# 9293      2    76         Usaquén          Usaquén  $ 370.000.000      $
#
#            Precio
# 4227  175.000.000
# 7500  250.000.000
# 9293  370.000.000

# %%
inmuebles.info() # los dos ultimos atributos aun sigen siendo str(objeto)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'].sum() # no habrá una respuesta correcta, solo concatenar
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True)  # reemplazaremos los puntos por espacios en blancos o nada, es muy importante el regex sino saldra error

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info() # el pinche precio sigue siendo objeto(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# convertimos el precio a float(decimal) para que sea mas facil leer los precio, otro xq se llama la variable Precio Millon
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.Precio_Millon
# Out:
# 0        360.00
# 1        670.00
# 2       1120.00
# 3        890.00
# 4        970.00
#          ...
# 9515     290.00
# 9516     670.00
# 9517     900.00
# 9518     335.00
# 9519     144.99
# Name: Precio_Millon, Length: 9520, dtype: float64

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 50) # un grafico con un histograma, el bins nos permite establecer el rango
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 100) # el histograma es para entender la frecuencia de una variable(en este caso el valor de los inmuebles)
# mientras mas bins, mas barras
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt # descargue de paqquetes para ver graficos
import seaborn as sns

plt.figure(figsize = (12, 8)) # establecer medidas al grafico(el tamaño) 10: ancho 8 altura
sns.histplot( data = inmuebles, x = 'Precio_Millon')
plt.show()

# %%
plt.figure(figsize = (12, 8)) 
grafica = sns.histplot( data = inmuebles, x = 'Precio_Millon')
grafica.set_title('Distribción de los Valores de los Inmuebles en Bogotá') # el titulo 
plt.xlim((50, 2000)) # como hay pocos inmuebles con numeros muy altos, por lo que extraeremos los limites y ver como se comportan los datos
plt.show()

# %%
plt.figure(figsize = (10, 6)) 
grafica = sns.histplot( data = inmuebles, x = 'Precio_Millon', kde = True) # K: curva de densidad
grafica.set_title('Distribción de los Valores de los Inmuebles en Bogotá') # el titulo 
plt.xlim((50, 1000)) 
plt.show()
# la curva que mas se ajusta al grafico

# %%
#como exportarlo (a img, ppt, pdf)
plt.figure(figsize = (10, 6)) 
grafica = sns.histplot( data = inmuebles, x = 'Precio_Millon', kde = True, hue = 'Tipo')  # hue es la leyenda
grafica.set_title('Distribción de los Valores de los Inmuebles en Bogotá') 
plt.xlim((50, 1000)) 
plt.savefig('/content/drive/MyDrive/Colab Notebooks/valor_Inmuebles.png', format = 'png')
plt.show()

# %%
plt.figure(figsize = (10, 6)) 
grafica = sns.histplot( data = inmuebles, x = 'Precio_Millon', kde = True, hue = 'Tipo') 
grafica.set_title('Distribción de los Valores de los Inmuebles en Bogotá') 
plt.xlim((50, 1000)) 
plt.ylim((0, 20))
plt.show()

# %% [markdown]
# # **Homework**

# %% [markdown]
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles(refinar el grafico: titulos, aumentar el tamaño de labels, colores, conclusion de la info)
#
# 2. Precio del metro cuadrado por barrio( que grafico representa la varible)

# %% [markdown]
# # AULA 03

# %%
#tomaremos como referencia el precio de todo el data set y luego dividir entre barrios
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon'] / inmuebles['Area']  #sumatoria de todos los precios para cada barrio y luego lo dividimos entre el area
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000          360.0             5.14
# 1    $ 670.000.000      $   670000000          670.0             3.94
# 2  $ 1.120.000.000      $  1120000000         1120.0             7.78

# %%
inmuebles.groupby('Barrio').mean() #ver el metro cuadrado por barrio, osea el promedio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00   97.00         580.00
# Alhambra                    3.00   2.94  190.41         752.35
# Andes Norte                 3.00   2.86  124.86         709.57
# Antonio Nariño              4.31   2.50  163.06         459.22
# Barrancas                   2.87   2.13   70.20         314.13
# ...                          ...    ...     ...            ...
# Villa Maria                 4.69   3.69  207.15         402.85
# Villas De Granada           3.45   2.32   86.59         282.30
# Villemar                    2.94   2.06   76.89         303.83
# Zona Franca                 2.00   1.00   54.00         160.00
# Zona Noroccidental          3.17   2.51  135.79         620.81
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                       4.33
# Andes Norte                    6.05
# Antonio Nariño                 3.53
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum() # sumar todos los precios de un barrio 
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/ datos_barrio['Area'] #divirlo por tod los metros cuadros de un barrio
datos_barrio['Valor_m2_Barrio'] # si impacta bastante la forma en como calcular datos
# Out:
# Barrio
# Alameda               5.98
# Alhambra              3.95
# Andes Norte           5.68
# Antonio Nariño        2.82
# Barrancas             4.47
#                       ...
# Villa Maria           1.94
# Villas De Granada     3.26
# Villemar              3.95
# Zona Franca           2.96
# Zona Noroccidental    4.57
# Name: Valor_m2_Barrio, Length: 149, dtype: float64

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio']) # creamos un diccionario del precio por metro cuadrado del barrio

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio'] # llevar el nuevo precio al valor barrio
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index # lista de indices de el contador de los 10 primero barrio(mas inmuebles a la venta)

# %%
# selecionar el top 10 de los barrios mas vendidos
datos_barrio.reset_index(inplace = True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios') #esta funcion nos mando el top 10 de los barrios
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
plt.figure(figsize = (10,8))
ax = sns.barplot(x = 'Barrio', y = 'Valor_m2_Barrio', data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation = 45) #los ticks son donde esta el punto de rotacion

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation = 45)
plt.show()
# cambiamos el data set de barrios, pero el boxplot sera en general
# nos muestra el valor min y max en quartiles

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation = 45)
plt.show()

# %%
plt.figure(figsize = (10,8))
ay = sns.boxplot(x = 'Barrio', y = 'Area', data = inmuebles.query('Barrio in @top_barrios & Area < 350'))
ay.tick_params(axis='x', rotation = 45)
plt.show() # debemos estar atentos a ls outlayers

# %%
plt.figure(figsize = (10,8))
az = sns.boxplot(x = 'Barrio', y = 'Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
az.tick_params(axis='x', rotation = 45)
plt.show() # la mediana es la liena que corta en 2 a la caja,

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Identificación (Capítulo A).csv', sep = ';', encoding = 'latin-1')
datos_raw.head() # es necesario poder el encoding para especifir algunos caracteres, es muy importante
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0    3.00e+06    11  11001      1            3.0         Santa Fe
# 1    3.00e+06    11  11001      1           14.0     Los Mártires
# 2    3.00e+06    11  11001      1            3.0         Santa Fe
# 3    3.00e+06    11  11001      1            1.0          Usaquén
# 4    3.00e+06    11  11001      1            1.0          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1           37.0                            Santa Isabel     11001162
# 2          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape #
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape # acabamos de eliminar 20mil regsitros que no son parte del area rural
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv', sep = ';', encoding = 'latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Educación (Capítulo H).csv', sep = ';', encoding = 'latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Fuerza de trabajo (Capítulo K).csv', sep = ';', encoding = 'latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';', encoding = 'latin-1')
# Out:
# <ipython-input-72-84b561361f87>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-72-84b561361f87>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
# <ipython-input-72-84b561361f87>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/Educación (Capítulo H).csv', sep = ';', encoding = 'latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw, datos_b, on = 'DIRECTORIO', how = 'left')  # left join en pandas 
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on = 'DIRECTORIO', how = 'left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how = 'left')
datos_dane.shape
# Out:
# <ipython-input-75-d044ea459036>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on = 'DIRECTORIO', how = 'left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %%
#hacemos left join, entonces sucede que el numero del directorio aumenta el numero de filas

# %% [markdown]
# # **Homework**

# %% [markdown]
# 1. Dar un vistazo a la BD dane, enterder variables  conceptualmente para entender mejor el contexto
# 2. Organizar el Notebook

# %% [markdown]
# # **AULA - 04**

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datos_dane.csv') #importar el nuevo de data set del desafio 
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0    3.00e+06          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1    3.00e+06          Usaquén                                        Usaquén
# 2    3.00e+06        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3    3.00e+06          Usaquén                                     Los Cedros
# 4    3.00e+06         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape # recordemos que la anterior clase hicismos una super base de miles de filas, pero con este db se optimizo
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {  #diccionario de datos de datos_dane 
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns = dic_dane) # renombramos el nombre de las columnas
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
# xq estudiar variables socioeconomicas para complementar nuestro modelo
# por lo que es necesario tener muchos mas datos

datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head() 
# sacamos el promedio y lo agrapamos por UPZs
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos  # remplazamos el no por el 0 (numero binario)
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.NOMBRE_ESTRATO.value_counts() # veremos que hay en cada estrato,
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0     9.80e+01              1.0
# ...

# %%
# calcular el promedio del data set de datos
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles,datos_tratados, left_on ='UPZ', right_on = 'NOMBRE_ESTRATO', how = 'left') # otro left join
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on ='UPZ', right_on = 'NOMBRE_ESTRATO', how = 'left')
# datos_ml es de machine learning
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valor_m2_Millon           9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %%
upz = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/archivos-dane/cod_upz.csv')
datos_ml = pd.merge(datos_ml, upz, left_on = 'UPZ', right_on = 'NOMBRE_ESTRATO', how = 'inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  TIENE_ESCRITURA  \
# ...

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valor_m2_Millon           9318 non-null   float64
#  12  Valor_m2_Barrio           9318 non-null   float64
# ...

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = datos_ml, y  = 'Precio_Millon')
plt.show() # hay muchisismos outlayer

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60') # sacar precios fuera de la caja de promedios
# ahora estamos refinando mas los datos, considerando varios factores
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 5000 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = datos_ml, y  = 'Precio_Millon')
plt.show()

# %%
# agregar el salario anual mediane el salario mensual 
datos_ml['SALARIO_ANUAL_ML'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_ML']
# Out:
# <ipython-input-129-533411ee05f6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_ml['SALARIO_ANUAL_ML'] = datos_ml['SALARIO_MES']*12/1000000
# 0       48.42
# 1       48.42
# 2       48.42
# 3       48.42
# 4       48.42
#         ...
# 9313    29.34
# 9314    29.34
# 9315    29.34
# 9316    29.34
# 9317    29.34
# Name: SALARIO_ANUAL_ML, Length: 9277, dtype: float64

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = datos_ml, x ='SALARIO_ANUAL_ML', y = 'Valor_m2_Millon') # como influye el valor m2 en millon en funcion del salario anual de las personas que habitan en estos barrio
#plt.ylim(()) # para limitar el limit en y 
plt.show() # todos los valores incluso los outlayers

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = datos_ml, x ='SALARIO_ANUAL_ML', y = 'Valor_m2_Millon') # como influye el valor m2 en millon en funcion del salario anual de las personas que habitan en estos barrio
plt.ylim((0, 15)) # para limitar el limit en y 
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(data = datos_ml, x ='SALARIO_ANUAL_ML', y = 'Valor_m2_Millon') #con otro tipo de grafica
plt.ylim((0, 15)) # para limitar el limit en y 
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(data = datos_ml, x ='SALARIO_ANUAL_ML', y = 'Valor_m2_Millon') #con otro tipo de grafica
#plt.ylim(()) # para limitar el limit en y 
plt.show()

# %%
datos_ml.corr() # -1 : inversamente correlacionada 1: directamente correlacionada, 0 : equilibrada
# Out:
#                           Habitaciones  Banos      Area  Precio_Millon  \
# Habitaciones                      1.00   0.48  3.43e-02           0.22
# Banos                             0.48   1.00  5.64e-02           0.65
# Area                              0.03   0.06  1.00e+00           0.05
# Precio_Millon                     0.22   0.65  5.44e-02           1.00
# Valor_m2_Millon                  -0.23   0.08 -3.59e-02           0.41
# Valor_m2_Barrio                  -0.18   0.16 -2.97e-02           0.32
# CONJUNTO_CERRADO                 -0.11   0.16 -7.06e-03           0.21
# INSEGURIDAD                       0.12  -0.19 -6.84e-03          -0.26
# TERMINALES_BUS                    0.06  -0.16 -1.18e-02          -0.18
# BARES_DISCO                       0.11  -0.08 -5.04e-03          -0.09
# RUIDO                             0.13  -0.18 -4.31e-03          -0.25
# OSCURO_PELIGROSO                  0.10  -0.20  6.91e-03          -0.23
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# generar un heatmap, para mirar un mapa de calor, una matriz que variales son mas optimas y cuales no

# %%
#machine learning : muchas ramificaciones
#nos enfocaremos en la funcion lineal, no supervionados, supervicionados

from sklearn.linear_model import LinearRegression # paquete de regresion lineal
from sklearn.model_selection import train_test_split # paquetes de separacion de conj de datos para entrenamients y de prueba, aplicar metodos de nuestro modelo, e, aplicar metricas

X = datos_ml[['COD_UPZ_GRUPO']] #introduccion de matriz en array
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size = 0.25, random_state = 99) #hacems un split de cada variable

# %%
X_train # datos del x prueba
# Out:
#       COD_UPZ_GRUPO
# 7578          810.0
# 8345           98.0
# 1246          816.0
# 8491          809.0
# 4602           47.0
# ...             ...
# 5223           19.0
# 7929           85.0
# 1784          817.0
# 3268           14.0
# 7242           20.0
#
# [6957 rows x 1 columns]

# %%
X_test # datos del x entrenamiento
# Out:
#       COD_UPZ_GRUPO
# 8428          809.0
# 3079           14.0
# 6927           75.0
# 6861           75.0
# 2357           14.0
# ...             ...
# 7777           85.0
# 1423          817.0
# 3916          803.0
# 8305           98.0
# 3989          803.0
#
# [2320 rows x 1 columns]

# %%
y_train # datos del y prueba
# Out:
# 7578    550.0
# 8345    700.0
# 1246    710.0
# 8491    400.0
# 4602    650.0
#         ...
# 5223    360.0
# 7929    119.0
# 1784    650.0
# 3268    350.0
# 7242    480.0
# Name: Precio_Millon, Length: 6957, dtype: float64

# %%
y_test # datos del y entrenamiento
# Out:
# 8428     650.0
# 3079     550.0
# 6927     327.0
# 6861     260.0
# 2357     460.0
#          ...
# 7777     131.0
# 1423     695.0
# 3916    1000.0
# 8305    1100.0
# 3989     265.0
# Name: Precio_Millon, Length: 2320, dtype: float64

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(X_test)

# %%
#error absoluto medio, toma la diferencia de valores que se puede encontrar a la hora del cambio
from sklearn.metrics import mean_absolute_error, r2_score # importe de metricas y el puntaje del cuadrado
baseline_mae = mean_absolute_error(y_test, y_predict_test)  #  instanciar el absoluto medio. comparará  el
baseline_mae  # el error absoluto
# Out:
# 349.01934464671155

# %%
baseline_r2 = r2_score(y_test, y_predict_test)
baseline_r2
# Out:
# 0.025479229587150987

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)  #imprimir la prueba y a los datos de entrenamiento
# Out:
# 241.7714514560005 0.39346598615451067
# 243.29145256483525 0.47023870196651907

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_ML','TIENE_ESCRITURA']] 

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 241.92824945672513 0.4253766410151324
# 243.25185242026816 0.48545749312201236
